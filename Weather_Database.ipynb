# %% [markdown]
# ## Deliverable 1

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        Weather_description=city_weather["weather"][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": Weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | grand gaube
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | geraldton
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | diamantino
# Processing Record 14 of Set 1 | bilibino
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | baruun-urt
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 1 | karratha
# Processing Record 23 of Set 1 | mount isa
# Processing Record 24 of Set 1 | shubarshi
# Processing Record 25 of Set 1 | tautira
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | ulladulla
# Processing Record 29 of Set 1 | constitucion
# Processing Record 30 of Set 1 | dubti
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | ancud
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | taoudenni
# Processing Record 39 of Set 1 | seoul
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | waterford
# Processing Record 42 of Set 1 | asau
# Processing Record 43 of Set 1 | minsk
# Processing Record 44 of Set 1 | pundaguitan
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | isangel
# Processing Record 47 of Set 1 | kanel
# Processing Record 48 of Set 1 | flin flon
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | gizo
# Processing Record 1 of Set 2 | saint-augustin
# Processing Record 2 of Set 2 | arco
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | coihaique
# Processing Record 5 of Set 2 | te anau
# Processing Record 6 of Set 2 | yunhe
# Processing Record 7 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | makakilo city
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | sjovegan
# Processing Record 11 of Set 2 | sobolevo
# Processing Record 12 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 13 of Set 2 | berlevag
# Processing Record 14 of Set 2 | pleasanton
# Processing Record 15 of Set 2 | tommot
# Processing Record 16 of Set 2 | lososina
# Processing Record 17 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 2 | jiutai
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | srednekolymsk
# Processing Record 23 of Set 2 | tulagi
# Processing Record 24 of Set 2 | kupang
# Processing Record 25 of Set 2 | north platte
# Processing Record 26 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | dzaoudzi
# Processing Record 29 of Set 2 | maragogi
# Processing Record 30 of Set 2 | sao felix do xingu
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | columbus
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | pauini
# Processing Record 36 of Set 2 | sanchursk
# Processing Record 37 of Set 2 | sorland
# Processing Record 38 of Set 2 | miracema do tocantins
# Processing Record 39 of Set 2 | aden
# Processing Record 40 of Set 2 | souillac
# Processing Record 41 of Set 2 | ourem
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | lakatoro
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | paso de los toros
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | port hedland
# Processing Record 49 of Set 2 | talaya
# Processing Record 50 of Set 2 | puerto guzman
# Processing Record 1 of Set 3 | kununurra
# Processing Record 2 of Set 3 | sambhal
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | igarka
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | port macquarie
# Processing Record 10 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 3 | gillette
# Processing Record 12 of Set 3 | barrow
# Processing Record 13 of Set 3 | werda
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | grants pass
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | oktyabrskoye
# Processing Record 20 of Set 3 | ostrovnoy
# Processing Record 21 of Set 3 | launceston
# Processing Record 22 of Set 3 | albany
# Processing Record 23 of Set 3 | dapaong
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | liyang
# Processing Record 27 of Set 3 | tura
# Processing Record 28 of Set 3 | ola
# Processing Record 29 of Set 3 | talakan
# Processing Record 30 of Set 3 | kathu
# Processing Record 31 of Set 3 | nabire
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | pyu
# Processing Record 34 of Set 3 | yialos
# City not found. Skipping...
# Processing Record 35 of Set 3 | yumen
# Processing Record 36 of Set 3 | guerrero negro
# Processing Record 37 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 3 | aykhal
# Processing Record 39 of Set 3 | tiarei
# Processing Record 40 of Set 3 | clyde river
# Processing Record 41 of Set 3 | axim
# Processing Record 42 of Set 3 | waseca
# Processing Record 43 of Set 3 | acapulco
# Processing Record 44 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | hays
# Processing Record 47 of Set 3 | okhotsk
# Processing Record 48 of Set 3 | broome
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | ust-maya
# Processing Record 1 of Set 4 | ponta do sol
# Processing Record 2 of Set 4 | ambon
# Processing Record 3 of Set 4 | kuna
# Processing Record 4 of Set 4 | sao luis de montes belos
# Processing Record 5 of Set 4 | sakakah
# Processing Record 6 of Set 4 | koslan
# Processing Record 7 of Set 4 | aklavik
# Processing Record 8 of Set 4 | hofn
# Processing Record 9 of Set 4 | gobabis
# Processing Record 10 of Set 4 | sao joao da barra
# Processing Record 11 of Set 4 | aktau
# Processing Record 12 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 4 | nyurba
# Processing Record 14 of Set 4 | nouadhibou
# Processing Record 15 of Set 4 | lata
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 18 of Set 4 | alakurtti
# Processing Record 19 of Set 4 | boddam
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | manado
# Processing Record 22 of Set 4 | severo-kurilsk
# Processing Record 23 of Set 4 | la ronge
# Processing Record 24 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 4 | shasta lake
# Processing Record 26 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 4 | kargil
# Processing Record 29 of Set 4 | payo
# Processing Record 30 of Set 4 | bac lieu
# Processing Record 31 of Set 4 | skiros
# City not found. Skipping...
# Processing Record 32 of Set 4 | erenhot
# Processing Record 33 of Set 4 | mount gambier
# Processing Record 34 of Set 4 | kaseda
# Processing Record 35 of Set 4 | tuktoyaktuk
# Processing Record 36 of Set 4 | sitka
# Processing Record 37 of Set 4 | san quintin
# Processing Record 38 of Set 4 | hirara
# Processing Record 39 of Set 4 | umm kaddadah
# Processing Record 40 of Set 4 | rio grande
# Processing Record 41 of Set 4 | richards bay
# Processing Record 42 of Set 4 | hulan ergi
# Processing Record 43 of Set 4 | hit
# Processing Record 44 of Set 4 | port elizabeth
# Processing Record 45 of Set 4 | rawson
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | mangrol
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | huarmey
# Processing Record 1 of Set 5 | logansport
# Processing Record 2 of Set 5 | carnarvon
# Processing Record 3 of Set 5 | itaqui
# Processing Record 4 of Set 5 | sombrerete
# Processing Record 5 of Set 5 | moranbah
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | boa vista
# Processing Record 8 of Set 5 | rangpur
# Processing Record 9 of Set 5 | yulara
# Processing Record 10 of Set 5 | cockburn town
# Processing Record 11 of Set 5 | fortuna
# Processing Record 12 of Set 5 | kingsport
# Processing Record 13 of Set 5 | dingle
# Processing Record 14 of Set 5 | marsh harbour
# Processing Record 15 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 16 of Set 5 | villa carlos paz
# Processing Record 17 of Set 5 | torbay
# Processing Record 18 of Set 5 | leningradskiy
# Processing Record 19 of Set 5 | superior
# Processing Record 20 of Set 5 | vestmannaeyjar
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | avera
# Processing Record 23 of Set 5 | saint-philippe
# Processing Record 24 of Set 5 | kismayo
# Processing Record 25 of Set 5 | natchez
# Processing Record 26 of Set 5 | hasaki
# Processing Record 27 of Set 5 | norman wells
# Processing Record 28 of Set 5 | alta floresta
# Processing Record 29 of Set 5 | camacha
# Processing Record 30 of Set 5 | fort nelson
# Processing Record 31 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 5 | pisco
# Processing Record 33 of Set 5 | durban
# Processing Record 34 of Set 5 | adrar
# Processing Record 35 of Set 5 | ust-kuyga
# Processing Record 36 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 5 | raga
# Processing Record 38 of Set 5 | epanomi
# Processing Record 39 of Set 5 | nanyuki
# Processing Record 40 of Set 5 | omboue
# Processing Record 41 of Set 5 | ondangwa
# Processing Record 42 of Set 5 | kaeo
# Processing Record 43 of Set 5 | faya
# Processing Record 44 of Set 5 | popondetta
# Processing Record 45 of Set 5 | maningrida
# Processing Record 46 of Set 5 | pacific grove
# Processing Record 47 of Set 5 | camana
# Processing Record 48 of Set 5 | gazojak
# Processing Record 49 of Set 5 | obo
# Processing Record 50 of Set 5 | penalva
# Processing Record 1 of Set 6 | diapaga
# Processing Record 2 of Set 6 | weinan
# Processing Record 3 of Set 6 | borna
# Processing Record 4 of Set 6 | airai
# Processing Record 5 of Set 6 | atar
# Processing Record 6 of Set 6 | bandarbeyla
# Processing Record 7 of Set 6 | yueyang
# Processing Record 8 of Set 6 | toktogul
# Processing Record 9 of Set 6 | lincoln
# Processing Record 10 of Set 6 | gari
# Processing Record 11 of Set 6 | saint-georges
# Processing Record 12 of Set 6 | namanyere
# Processing Record 13 of Set 6 | abha
# Processing Record 14 of Set 6 | burhar
# Processing Record 15 of Set 6 | friesach
# Processing Record 16 of Set 6 | neuquen
# Processing Record 17 of Set 6 | nicolet
# Processing Record 18 of Set 6 | abu samrah
# Processing Record 19 of Set 6 | west bay
# Processing Record 20 of Set 6 | hithadhoo
# Processing Record 21 of Set 6 | marzuq
# Processing Record 22 of Set 6 | nemuro
# Processing Record 23 of Set 6 | namibe
# Processing Record 24 of Set 6 | kodiak
# Processing Record 25 of Set 6 | taraz
# Processing Record 26 of Set 6 | pitimbu
# Processing Record 27 of Set 6 | thinadhoo
# Processing Record 28 of Set 6 | ozernovskiy
# Processing Record 29 of Set 6 | haines junction
# Processing Record 30 of Set 6 | opuwo
# Processing Record 31 of Set 6 | hoi an
# Processing Record 32 of Set 6 | kloulklubed
# Processing Record 33 of Set 6 | bud
# Processing Record 34 of Set 6 | nogent-le-rotrou
# Processing Record 35 of Set 6 | babanka
# Processing Record 36 of Set 6 | padang
# Processing Record 37 of Set 6 | anloga
# Processing Record 38 of Set 6 | broken hill
# Processing Record 39 of Set 6 | laguna
# Processing Record 40 of Set 6 | los llanos de aridane
# Processing Record 41 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 42 of Set 6 | cradock
# Processing Record 43 of Set 6 | mahebourg
# Processing Record 44 of Set 6 | hobyo
# Processing Record 45 of Set 6 | iqaluit
# Processing Record 46 of Set 6 | ayios matthaios
# City not found. Skipping...
# Processing Record 47 of Set 6 | elvange
# Processing Record 48 of Set 6 | epernay
# Processing Record 49 of Set 6 | linxia
# Processing Record 50 of Set 6 | orlik
# Processing Record 1 of Set 7 | grindavik
# Processing Record 2 of Set 7 | upernavik
# Processing Record 3 of Set 7 | klaksvik
# Processing Record 4 of Set 7 | ciudad bolivar
# Processing Record 5 of Set 7 | vacaria
# Processing Record 6 of Set 7 | nikolskoye
# Processing Record 7 of Set 7 | saint anthony
# Processing Record 8 of Set 7 | mastic beach
# Processing Record 9 of Set 7 | periyanayakkanpalaiyam
# Processing Record 10 of Set 7 | verkhnyaya inta
# Processing Record 11 of Set 7 | yuncheng
# Processing Record 12 of Set 7 | cayenne
# Processing Record 13 of Set 7 | shikarpur
# Processing Record 14 of Set 7 | codrington
# Processing Record 15 of Set 7 | sao filipe
# Processing Record 16 of Set 7 | college
# Processing Record 17 of Set 7 | san policarpo
# Processing Record 18 of Set 7 | turukhansk
# Processing Record 19 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 7 | tandil
# Processing Record 21 of Set 7 | harper
# Processing Record 22 of Set 7 | tottori
# Processing Record 23 of Set 7 | bathsheba
# Processing Record 24 of Set 7 | ponta delgada
# Processing Record 25 of Set 7 | goma
# Processing Record 26 of Set 7 | hibbing
# Processing Record 27 of Set 7 | medvezhyegorsk
# Processing Record 28 of Set 7 | lagoa
# Processing Record 29 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 7 | lavrentiya
# Processing Record 31 of Set 7 | luderitz
# Processing Record 32 of Set 7 | pokosnoye
# Processing Record 33 of Set 7 | faanui
# Processing Record 34 of Set 7 | mercedes
# Processing Record 35 of Set 7 | katherine
# Processing Record 36 of Set 7 | kingsville
# Processing Record 37 of Set 7 | micheweni
# Processing Record 38 of Set 7 | khargapur
# Processing Record 39 of Set 7 | pevek
# Processing Record 40 of Set 7 | port said
# Processing Record 41 of Set 7 | sapele
# Processing Record 42 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 7 | plouzane
# Processing Record 44 of Set 7 | suntar
# Processing Record 45 of Set 7 | fairbanks
# Processing Record 46 of Set 7 | labuhan
# Processing Record 47 of Set 7 | kavaratti
# Processing Record 48 of Set 7 | datong
# Processing Record 49 of Set 7 | vila velha
# Processing Record 50 of Set 7 | sur
# Processing Record 1 of Set 8 | bengkulu
# Processing Record 2 of Set 8 | ninghai
# Processing Record 3 of Set 8 | ouadda
# Processing Record 4 of Set 8 | awjilah
# Processing Record 5 of Set 8 | mweka
# Processing Record 6 of Set 8 | leh
# Processing Record 7 of Set 8 | salmas
# Processing Record 8 of Set 8 | emerald
# Processing Record 9 of Set 8 | barcelos
# Processing Record 10 of Set 8 | bedele
# Processing Record 11 of Set 8 | kambove
# Processing Record 12 of Set 8 | tarn taran
# Processing Record 13 of Set 8 | platteville
# Processing Record 14 of Set 8 | sabha
# Processing Record 15 of Set 8 | asheville
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | maniitsoq
# Processing Record 18 of Set 8 | meulaboh
# Processing Record 19 of Set 8 | inhambane
# Processing Record 20 of Set 8 | port hardy
# Processing Record 21 of Set 8 | vao
# Processing Record 22 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 23 of Set 8 | nantucket
# Processing Record 24 of Set 8 | angoche
# Processing Record 25 of Set 8 | pangnirtung
# Processing Record 26 of Set 8 | gubkinskiy
# Processing Record 27 of Set 8 | curitibanos
# Processing Record 28 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 8 | anchorage
# Processing Record 30 of Set 8 | kyzyl-suu
# Processing Record 31 of Set 8 | chimore
# Processing Record 32 of Set 8 | alofi
# Processing Record 33 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 34 of Set 8 | yining
# Processing Record 35 of Set 8 | mocuba
# Processing Record 36 of Set 8 | teberda
# Processing Record 37 of Set 8 | mlonggo
# Processing Record 38 of Set 8 | roald
# Processing Record 39 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 40 of Set 8 | gura calitei
# Processing Record 41 of Set 8 | jimenez
# Processing Record 42 of Set 8 | san cristobal
# Processing Record 43 of Set 8 | quatre cocos
# Processing Record 44 of Set 8 | ongandjera
# Processing Record 45 of Set 8 | malasin
# Processing Record 46 of Set 8 | marfino
# Processing Record 47 of Set 8 | kuryk
# Processing Record 48 of Set 8 | verkhnevilyuysk
# Processing Record 49 of Set 8 | dubbo
# Processing Record 50 of Set 8 | campobasso
# Processing Record 1 of Set 9 | el tocuyo
# Processing Record 2 of Set 9 | morelia
# Processing Record 3 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 4 of Set 9 | santiago
# Processing Record 5 of Set 9 | port lincoln
# Processing Record 6 of Set 9 | alice springs
# Processing Record 7 of Set 9 | lima
# Processing Record 8 of Set 9 | moose factory
# Processing Record 9 of Set 9 | murgab
# Processing Record 10 of Set 9 | mareeba
# Processing Record 11 of Set 9 | ambanja
# Processing Record 12 of Set 9 | tutoia
# Processing Record 13 of Set 9 | sterling
# Processing Record 14 of Set 9 | kennett
# Processing Record 15 of Set 9 | sandnessjoen
# Processing Record 16 of Set 9 | takoradi
# Processing Record 17 of Set 9 | ilulissat
# Processing Record 18 of Set 9 | voznesenye
# Processing Record 19 of Set 9 | salalah
# Processing Record 20 of Set 9 | saint george
# Processing Record 21 of Set 9 | mendi
# Processing Record 22 of Set 9 | moctezuma
# Processing Record 23 of Set 9 | vanavara
# Processing Record 24 of Set 9 | marrakesh
# Processing Record 25 of Set 9 | zaigrayevo
# Processing Record 26 of Set 9 | bonthe
# Processing Record 27 of Set 9 | vanimo
# Processing Record 28 of Set 9 | ossora
# Processing Record 29 of Set 9 | resende
# Processing Record 30 of Set 9 | birao
# Processing Record 31 of Set 9 | kirkenaer
# Processing Record 32 of Set 9 | cardston
# Processing Record 33 of Set 9 | batagay-alyta
# Processing Record 34 of Set 9 | nguruka
# Processing Record 35 of Set 9 | hambantota
# Processing Record 36 of Set 9 | tual
# Processing Record 37 of Set 9 | roebourne
# Processing Record 38 of Set 9 | gat
# Processing Record 39 of Set 9 | warrnambool
# Processing Record 40 of Set 9 | gbarnga
# Processing Record 41 of Set 9 | boralday
# Processing Record 42 of Set 9 | chapleau
# Processing Record 43 of Set 9 | bambanglipuro
# Processing Record 44 of Set 9 | coquimbo
# Processing Record 45 of Set 9 | buala
# Processing Record 46 of Set 9 | hun
# Processing Record 47 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 48 of Set 9 | gisborne
# Processing Record 49 of Set 9 | albania
# Processing Record 50 of Set 9 | penjamo
# Processing Record 1 of Set 10 | nkhata bay
# Processing Record 2 of Set 10 | westport
# Processing Record 3 of Set 10 | mersing
# Processing Record 4 of Set 10 | rincon
# Processing Record 5 of Set 10 | sabang
# Processing Record 6 of Set 10 | rozkishne
# Processing Record 7 of Set 10 | liverpool
# Processing Record 8 of Set 10 | arraial do cabo
# Processing Record 9 of Set 10 | luanda
# Processing Record 10 of Set 10 | georgiyevskoye
# Processing Record 11 of Set 10 | ferme-neuve
# Processing Record 12 of Set 10 | sao pedro do sul
# Processing Record 13 of Set 10 | amarante do maranhao
# Processing Record 14 of Set 10 | kui buri
# Processing Record 15 of Set 10 | wahiawa
# Processing Record 16 of Set 10 | aguililla
# Processing Record 17 of Set 10 | vostok
# Processing Record 18 of Set 10 | beeville
# Processing Record 19 of Set 10 | inongo
# Processing Record 20 of Set 10 | venice
# Processing Record 21 of Set 10 | touros
# Processing Record 22 of Set 10 | samarai
# Processing Record 23 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 24 of Set 10 | anadyr
# Processing Record 25 of Set 10 | najran
# Processing Record 26 of Set 10 | half moon bay
# Processing Record 27 of Set 10 | byron bay
# Processing Record 28 of Set 10 | boyolangu
# Processing Record 29 of Set 10 | coos bay
# Processing Record 30 of Set 10 | olafsvik
# Processing Record 31 of Set 10 | progreso
# Processing Record 32 of Set 10 | luganville
# Processing Record 33 of Set 10 | khasan
# Processing Record 34 of Set 10 | khor
# Processing Record 35 of Set 10 | kota belud
# Processing Record 36 of Set 10 | atambua
# Processing Record 37 of Set 10 | yerbogachen
# Processing Record 38 of Set 10 | tlacoyalco
# City not found. Skipping...
# Processing Record 39 of Set 10 | nagato
# Processing Record 40 of Set 10 | cabedelo
# Processing Record 41 of Set 10 | taltal
# Processing Record 42 of Set 10 | nishihara
# Processing Record 43 of Set 10 | kapit
# Processing Record 44 of Set 10 | ambilobe
# Processing Record 45 of Set 10 | vila franca do campo
# Processing Record 46 of Set 10 | belaya gora
# Processing Record 47 of Set 10 | tazovskiy
# Processing Record 48 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 10 | mbala
# Processing Record 50 of Set 10 | flinders
# Processing Record 1 of Set 11 | nanning
# Processing Record 2 of Set 11 | mayo
# Processing Record 3 of Set 11 | jacareacanga
# Processing Record 4 of Set 11 | homer
# Processing Record 5 of Set 11 | pokhara
# Processing Record 6 of Set 11 | escarcega
# Processing Record 7 of Set 11 | valdosta
# Processing Record 8 of Set 11 | okakarara
# Processing Record 9 of Set 11 | dunedin
# Processing Record 10 of Set 11 | monroe
# Processing Record 11 of Set 11 | zhaoyang
# Processing Record 12 of Set 11 | canguaretama
# Processing Record 13 of Set 11 | kargasok
# Processing Record 14 of Set 11 | homestead
# Processing Record 15 of Set 11 | vagur
# Processing Record 16 of Set 11 | lucea
# Processing Record 17 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 18 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 11 | tarata
# Processing Record 20 of Set 11 | pierre
# Processing Record 21 of Set 11 | christchurch
# Processing Record 22 of Set 11 | mazagao
# Processing Record 23 of Set 11 | nyanza
# Processing Record 24 of Set 11 | poum
# Processing Record 25 of Set 11 | batar
# Processing Record 26 of Set 11 | severo-yeniseyskiy
# Processing Record 27 of Set 11 | kalmunai
# Processing Record 28 of Set 11 | palmer
# Processing Record 29 of Set 11 | lompoc
# Processing Record 30 of Set 11 | muros
# Processing Record 31 of Set 11 | ritchie
# Processing Record 32 of Set 11 | amapa
# Processing Record 33 of Set 11 | kushima
# Processing Record 34 of Set 11 | turaiyur
# Processing Record 35 of Set 11 | gornopravdinsk
# Processing Record 36 of Set 11 | kangaatsiaq
# Processing Record 37 of Set 11 | lyngseidet
# Processing Record 38 of Set 11 | garowe
# Processing Record 39 of Set 11 | binzhou
# Processing Record 40 of Set 11 | tomatlan
# Processing Record 41 of Set 11 | almaznyy
# Processing Record 42 of Set 11 | ixtapa
# Processing Record 43 of Set 11 | altay
# Processing Record 44 of Set 11 | marystown
# Processing Record 45 of Set 11 | kalabo
# Processing Record 46 of Set 11 | talnakh
# Processing Record 47 of Set 11 | lakes entrance
# Processing Record 48 of Set 11 | high level
# Processing Record 49 of Set 11 | rafai
# Processing Record 50 of Set 11 | paamiut
# Processing Record 1 of Set 12 | kizukuri
# Processing Record 2 of Set 12 | alekseyevsk
# Processing Record 3 of Set 12 | terrace
# Processing Record 4 of Set 12 | ojinaga
# Processing Record 5 of Set 12 | resistencia
# Processing Record 6 of Set 12 | funadhoo
# Processing Record 7 of Set 12 | ayorou
# Processing Record 8 of Set 12 | peto
# Processing Record 9 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 12 | beaumont
# Processing Record 11 of Set 12 | griffith
# Processing Record 12 of Set 12 | rotifunk
# Processing Record 13 of Set 12 | damietta
# Processing Record 14 of Set 12 | bauchi
# Processing Record 15 of Set 12 | guayabal
# Processing Record 16 of Set 12 | narsaq
# Processing Record 17 of Set 12 | great yarmouth
# Processing Record 18 of Set 12 | pinheiro machado
# Processing Record 19 of Set 12 | oranjemund
# Processing Record 20 of Set 12 | mackay
# Processing Record 21 of Set 12 | nalut
# Processing Record 22 of Set 12 | juneau
# Processing Record 23 of Set 12 | poronaysk
# Processing Record 24 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 25 of Set 12 | yarega
# Processing Record 26 of Set 12 | san joaquin
# Processing Record 27 of Set 12 | navadwip
# Processing Record 28 of Set 12 | ferrandina
# Processing Record 29 of Set 12 | lana
# Processing Record 30 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 12 | bahia honda
# Processing Record 32 of Set 12 | ahuimanu
# Processing Record 33 of Set 12 | artigas
# Processing Record 34 of Set 12 | lubumbashi
# Processing Record 35 of Set 12 | rabo de peixe
# Processing Record 36 of Set 12 | ambunti
# Processing Record 37 of Set 12 | stephenville crossing
# Processing Record 38 of Set 12 | tonantins
# Processing Record 39 of Set 12 | darhan
# Processing Record 40 of Set 12 | abilene
# Processing Record 41 of Set 12 | jalu
# Processing Record 42 of Set 12 | dmitriyevka
# Processing Record 43 of Set 12 | port moresby
# Processing Record 44 of Set 12 | skibbereen
# Processing Record 45 of Set 12 | tateyama
# Processing Record 46 of Set 12 | tallahassee
# Processing Record 47 of Set 12 | barranca
# Processing Record 48 of Set 12 | sembakung
# Processing Record 49 of Set 12 | dudinka
# Processing Record 50 of Set 12 | lorengau
# Processing Record 1 of Set 13 | gonbad-e qabus
# Processing Record 2 of Set 13 | devils lake
# Processing Record 3 of Set 13 | arequipa
# Processing Record 4 of Set 13 | santa fe
# Processing Record 5 of Set 13 | nampula
# Processing Record 6 of Set 13 | tecpan
# Processing Record 7 of Set 13 | sao jose da coroa grande
# Processing Record 8 of Set 13 | kaohsiung
# Processing Record 9 of Set 13 | itarema
# Processing Record 10 of Set 13 | navoi
# Processing Record 11 of Set 13 | belmonte
# Processing Record 12 of Set 13 | owase
# Processing Record 13 of Set 13 | lac
# Processing Record 14 of Set 13 | carballo
# Processing Record 15 of Set 13 | okulovka
# Processing Record 16 of Set 13 | muisne
# Processing Record 17 of Set 13 | callaguip
# Processing Record 18 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 19 of Set 13 | chimbote
# Processing Record 20 of Set 13 | carutapera
# Processing Record 21 of Set 13 | sawtell
# Processing Record 22 of Set 13 | carauari
# Processing Record 23 of Set 13 | noboribetsu
# Processing Record 24 of Set 13 | aksu
# Processing Record 25 of Set 13 | bubaque
# Processing Record 26 of Set 13 | manakara
# Processing Record 27 of Set 13 | sibenik
# Processing Record 28 of Set 13 | melo
# Processing Record 29 of Set 13 | manitowoc
# Processing Record 30 of Set 13 | kyshtovka
# Processing Record 31 of Set 13 | aguimes
# Processing Record 32 of Set 13 | iskandar
# Processing Record 33 of Set 13 | sola
# Processing Record 34 of Set 13 | sambava
# Processing Record 35 of Set 13 | pumiao
# Processing Record 36 of Set 13 | jining
# Processing Record 37 of Set 13 | igra
# Processing Record 38 of Set 13 | san rafael
# Processing Record 39 of Set 13 | kostomuksha
# Processing Record 40 of Set 13 | manicore
# Processing Record 41 of Set 13 | teya
# Processing Record 42 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 13 | aksarka
# Processing Record 44 of Set 13 | cabo san lucas
# Processing Record 45 of Set 13 | maciel
# Processing Record 46 of Set 13 | banda aceh
# Processing Record 47 of Set 13 | barkhan
# Processing Record 48 of Set 13 | evensk
# Processing Record 49 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 50 of Set 13 | zhigansk
# Processing Record 1 of Set 14 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 2 of Set 14 | manzhouli
# Processing Record 3 of Set 14 | umm lajj
# Processing Record 4 of Set 14 | aketi
# Processing Record 5 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 14 | lahat
# Processing Record 7 of Set 14 | kitimat
# Processing Record 8 of Set 14 | dandong
# Processing Record 9 of Set 14 | wagga wagga
# Processing Record 10 of Set 14 | savannah bight
# Processing Record 11 of Set 14 | singaraja
# Processing Record 12 of Set 14 | zhanaozen
# Processing Record 13 of Set 14 | fare
# Processing Record 14 of Set 14 | comodoro rivadavia
# Processing Record 15 of Set 14 | hokitika
# Processing Record 16 of Set 14 | auki
# Processing Record 17 of Set 14 | necochea
# Processing Record 18 of Set 14 | george town
# Processing Record 19 of Set 14 | san martin
# Processing Record 20 of Set 14 | ballina
# Processing Record 21 of Set 14 | invermere
# Processing Record 22 of Set 14 | leshukonskoye
# Processing Record 23 of Set 14 | novoagansk
# Processing Record 24 of Set 14 | nicoya
# Processing Record 25 of Set 14 | goundam
# Processing Record 26 of Set 14 | abong mbang
# Processing Record 27 of Set 14 | coahuayana
# Processing Record 28 of Set 14 | trelew
# Processing Record 29 of Set 14 | roma
# Processing Record 30 of Set 14 | aloleng
# Processing Record 31 of Set 14 | nizhnyaya tavda
# Processing Record 32 of Set 14 | almora
# Processing Record 33 of Set 14 | tacuati
# Processing Record 34 of Set 14 | sinnamary
# Processing Record 35 of Set 14 | rocha
# Processing Record 36 of Set 14 | zharkent
# Processing Record 37 of Set 14 | pozo colorado
# Processing Record 38 of Set 14 | dutlwe
# Processing Record 39 of Set 14 | mackenzie
# Processing Record 40 of Set 14 | general roca
# Processing Record 41 of Set 14 | praia da vitoria
# Processing Record 42 of Set 14 | beringovskiy
# Processing Record 43 of Set 14 | east foothills
# Processing Record 44 of Set 14 | muroto
# Processing Record 45 of Set 14 | firovo
# Processing Record 46 of Set 14 | karaton
# Processing Record 47 of Set 14 | vila
# Processing Record 48 of Set 14 | maroua
# Processing Record 49 of Set 14 | itaquyry
# Processing Record 50 of Set 14 | korla
# Processing Record 1 of Set 15 | lasa
# Processing Record 2 of Set 15 | anshun
# Processing Record 3 of Set 15 | maarianhamina
# Processing Record 4 of Set 15 | tshikapa
# Processing Record 5 of Set 15 | upata
# Processing Record 6 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 15 | haukipudas
# Processing Record 8 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 15 | piryion
# City not found. Skipping...
# Processing Record 10 of Set 15 | inuvik
# Processing Record 11 of Set 15 | imeni poliny osipenko
# Processing Record 12 of Set 15 | grajau
# Processing Record 13 of Set 15 | manhattan
# Processing Record 14 of Set 15 | la macarena
# Processing Record 15 of Set 15 | tupik
# Processing Record 16 of Set 15 | birjand
# Processing Record 17 of Set 15 | saint-joseph
# Processing Record 18 of Set 15 | burica
# City not found. Skipping...
# Processing Record 19 of Set 15 | deputatskiy
# Processing Record 20 of Set 15 | gwadar
# Processing Record 21 of Set 15 | dalby
# Processing Record 22 of Set 15 | dolores
# Processing Record 23 of Set 15 | bull savanna
# Processing Record 24 of Set 15 | la gomera
# Processing Record 25 of Set 15 | balsas
# Processing Record 26 of Set 15 | north bend
# Processing Record 27 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 15 | basco
# Processing Record 29 of Set 15 | viedma
# Processing Record 30 of Set 15 | cartagena
# Processing Record 31 of Set 15 | balikpapan
# Processing Record 32 of Set 15 | pietermaritzburg
# Processing Record 33 of Set 15 | bridgetown
# Processing Record 34 of Set 15 | solnechnyy
# Processing Record 35 of Set 15 | mogocha
# Processing Record 36 of Set 15 | peniche
# Processing Record 37 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 38 of Set 15 | chillicothe
# Processing Record 39 of Set 15 | bara
# Processing Record 40 of Set 15 | belyy yar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga  71.9667  102.5000    -27.13        79          41
# 1       Mataura -46.1927  168.8643     47.43        94         100
# 2    Georgetown   5.4112  100.3354     84.00        83          20
# 3   Grand Gaube -20.0064   57.6608     79.00        77           0
# 4        Hobart -42.8794  147.3294     69.80        83          90
# 5     Geraldton -28.7667  114.6000     66.20        77          90
# 6  Punta Arenas -53.1500  -70.9167     55.40        50          20
# 7      Hamilton  39.1834  -84.5333     32.00        55          20
# 8       Qaanaaq  77.4840  -69.3632    -14.06        72          25
# 9  Kruisfontein -34.0033   24.7314     78.01        62           0
#
#    Wind Speed Country Current Description
# 0        8.63      RU    scattered clouds
# 1        1.50      NZ     overcast clouds
# 2        2.30      MY          few clouds
# 3        1.99      MU           clear sky
# 4       10.36      AU          light rain
# 5       11.50      AU          light rain
# 6       24.16      CL          few clouds
# 7       11.50      US          few clouds
# 8        6.49      GL    scattered clouds
# 9        7.00      ZA           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
